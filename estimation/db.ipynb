# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

# %%
import os
import subprocess

def get_repo_root():
    try:
        repo_root = subprocess.check_output(['git', 'rev-parse', '--show-toplevel'], stderr=subprocess.STDOUT)
        return repo_root.strip().decode('utf-8')
    except subprocess.CalledProcessError as e:
        return None

repo_root = get_repo_root()

# %%
pd.set_option('display.max_rows', 25)
pd.set_option('display.max_columns', 100)

directory_path =  "estimation/tsv_export"
directory_path = os.path.join(repo_root, directory_path)
tables = {}

for file_name in os.listdir(directory_path):
    if file_name.endswith(".tsv"):  # Check if the file has a .tsv extension
        file_path = os.path.join(directory_path, file_name)  # Full path to the file
        try:
            df = pd.read_csv(file_path, sep='\t', low_memory=False)
            tables[file_name] = df
            print(f"Loaded {file_name} with shape {df.shape}")
        except Exception as e:
            print(f"Error reading {file_name}: {e}")

for file_name, df in tables.items():
    print(f"First 5 rows of {file_name}:")
    display(df.head())
# Out:
# Loaded WCA_export_championships.tsv with shape (740, 3)
# Loaded WCA_export_Competitions.tsv with shape (13759, 21)
# Loaded WCA_export_Continents.tsv with shape (7, 6)
# Loaded WCA_export_Countries.tsv with shape (207, 4)
# Loaded WCA_export_eligible_country_iso2s_for_championship.tsv with shape (4, 2)
# Loaded WCA_export_Events.tsv with shape (21, 5)
# Loaded WCA_export_Formats.tsv with shape (5, 7)
# Loaded WCA_export_Persons.tsv with shape (248820, 5)
# Loaded WCA_export_RanksAverage.tsv with shape (749202, 6)
# Loaded WCA_export_RanksSingle.tsv with shape (867170, 6)
# Loaded WCA_export_Results.tsv with shape (5144555, 17)
# Loaded WCA_export_RoundTypes.tsv with shape (11, 5)
# Loaded WCA_export_Scrambles.tsv with shape (2324686, 8)
# First 5 rows of WCA_export_championships.tsv:
#     id         competition_id championship_type
# 0  506  ACA5thAnniversary2020                AZ
# 1  328              ACARO2016                HK
# 2  170  AFSwedishCubeOpen2016                SE
# 3  326       AlbanianOpen2018                AL
# 4  414       AlbanianOpen2019                AL
# First 5 rows of WCA_export_Competitions.tsv:
#                              id                               name  \
# 0                 100Merito2018                   100º Mérito 2018
# 1    100YearsRepublicAnkara2023     100 Years Republic Ankara 2023
# 2  100YearsRepublicIstanbul2023   100 Years Republic İstanbul 2023
# 3      100YilMBACubeWeekend2023     100. Yıl MBA Cube Weekend 2023
# 4    10AniversarioGuatemala2023  Décimo Aniversario Guatemala 2023
#
#          cityName  countryId  \
# 0  Santarém, Pará     Brazil
# 1          Ankara     Turkey
# 2        İstanbul     Turkey
# 3        İstanbul     Turkey
# 4  Guatemala City  Guatemala
#
#                                          information  \
# 0  Qualquer pessoa que resolva o Cubo Mágico em m...
# 1  [TR] Kayıt sırasında adınızı ve soyadınızı lüt...
# 2  [TR] Kayıt sırasında adınızı ve soyadınızı lüt...
# 3  [TR] Kayıt sırasında adınızı ve soyadınızı lüt...
# 4  Ésta es una competencia conmemorativa en honor...
#
#                                                venue  \
# 0  [Mérito Pré-Vestibulares](https://www.facebook...
# 1   TMMOB Teoman Öztürk Öğrenci Evi ve Sosyal Tesisi
# 2  [Bil Koleji Ümraniye Yerleşkesi](https://bilok...
# 3  [MBA Okulları Çamlıca Yerleşkesi](https://www....
# 4               [Colegio Caré](https://care.edu.gt/)
#
#                                         venueAddress  \
# 0     Avenida Mendonça Furtado, 1120 - CEP: 68040050
# 1  Mehmet Akif Ersoy, 295. Sk. No:6, 06200 Yenima...
# 2  Cemil Meriç, Alemdağ Cd No:321, 34771 Dudullu ...
# 3  Küçük Çamlıca, Libadiye Cd. No:30, 34692 Üsküd...
# 4                            23 calle 15-45, zona 13
#
#                        venueDetails external_website  \
# 0  Próximo ao Colégio São Francisco              NaN
# 1                 6.kat / 6th floor              NaN
# 2                        Yemek katı              NaN
# 3           Yemekhane / Dining Hall              NaN
# 4                               NaN              NaN
#
#                            cellName  latitude  longitude  cancelled  \
# 0                  100º Mérito 2018  -2422498  -54712597          0
# 1    100 Years Republic Ankara 2023  39964026   32766238          0
# 2  100 Years Republic İstanbul 2023  41016582   29142873          0
# 3    100. Yıl MBA Cube Weekend 2023  41012107   29074717          0
# 4     10 Aniversario Guatemala 2023  14573384  -90525865          1
#
#                                           eventSpecs  \
# 0                222 333 333bf 333ft 444 pyram skewb
# 1        222 333 333oh 444 555 clock pyram skewb sq1
# 2  222 333 333bf 333oh 444 555 clock pyram skewb sq1
# 3  222 333 333bf 333oh 444 555 666 777 clock minx...
# 4             222 333 333bf 333oh 444 555 minx pyram
#
#                                          wcaDelegate  \
# 0  [{Rafael de Andrade Cinoto}{mailto:rcinoto@wor...
# 1  [{Can Ersoy}{mailto:cersoy@worldcubeassociatio...
# 2  [{Mustafa Çamlıca}{mailto:mcamlica@worldcubeas...
# 3  [{Mustafa Çamlıca}{mailto:mcamlica@worldcubeas...
# 4  [{Adrián Ramírez}{mailto:aramirez@worldcubeass...
#
#                                            organiser  year  month  day  \
# 0  [{Davi de Andrade Iácono}{mailto:diacono@world...  2018      4   14
# 1  [{İskender Aznavur}{mailto:i.kuleli@gmail.com}...  2023     10   28
# 2  [{Alper Şakım}{mailto:alpersakim2@gmail.com}] ...  2023     10   28
# 3  [{Alper Şakım}{mailto:alpersakim2@gmail.com}] ...  2023     12   16
# 4    [{Nancy Ramírez}{mailto:nancy.r1116@gmail.com}]  2023     10   14
#
#    endMonth  endDay
# 0         4      14
# 1        10      29
# 2        10      29
# 3        12      17
# 4        10      15
# First 5 rows of WCA_export_Continents.tsv:
#                      id  latitude  longitude                 name recordName  \
# 0               _Africa    213671   16984850               Africa        AfR
# 1                 _Asia  34364439  108330700                 Asia        AsR
# 2               _Europe  58299984   23049300               Europe         ER
# 3  _Multiple Continents         0          0  Multiple Continents        NaN
# 4        _North America  45486546  -93449700        North America        NAR
#
#    zoom
# 0     3
# 1     2
# 2     3
# 3     1
# 4     3
# First 5 rows of WCA_export_Countries.tsv:
#             id continentId iso2         name
# 0  Afghanistan       _Asia   AF  Afghanistan
# 1      Albania     _Europe   AL      Albania
# 2      Algeria     _Africa   DZ      Algeria
# 3      Andorra     _Europe   AD      Andorra
# 4       Angola     _Africa   AO       Angola
# First 5 rows of WCA_export_eligible_country_iso2s_for_championship.tsv:
#   championship_type eligible_country_iso2
# 0     greater_china                    CN
# 1     greater_china                    HK
# 2     greater_china                    MO
# 3     greater_china                    TW
# First 5 rows of WCA_export_Events.tsv:
#       id  format                name  rank            cellName
# 0    222    time          2x2x2 Cube    20          2x2x2 Cube
# 1    333    time          3x3x3 Cube    10          3x3x3 Cube
# 2  333bf    time   3x3x3 Blindfolded    70   3x3x3 Blindfolded
# 3  333fm  number  3x3x3 Fewest Moves    80  3x3x3 Fewest Moves
# 4  333ft    time     3x3x3 With Feet   996     3x3x3 With Feet
# First 5 rows of WCA_export_Formats.tsv:
#   id  expected_solve_count          name  sort_by sort_by_second  \
# 0  1                     1     Best of 1   single        average
# 1  2                     2     Best of 2   single        average
# 2  3                     3     Best of 3   single        average
# 3  a                     5  Average of 5  average         single
# 4  m                     3     Mean of 3  average         single
#
#    trim_fastest_n  trim_slowest_n
# 0               0               0
# 1               0               0
# 2               0               0
# 3               1               1
# 4               0               0
# First 5 rows of WCA_export_Persons.tsv:
#    subid              name       countryId gender          id
# 0      1     Jozsef Borsos          Serbia      m  1982BORS01
# 1      1  Roland Brinkmann         Germany      m  1982BRIN01
# 2      1   Julian Chilvers  United Kingdom      m  1982CHIL01
# 3      1  Jessica Fridrich             USA      f  1982FRID01
# 4      2  Jessica Fridrich  Czech Republic      f  1982FRID01
# First 5 rows of WCA_export_RanksAverage.tsv:
#      personId eventId  best  worldRank  continentRank  countryRank
# 0  2019WANY36     222    92          1              1            1
# 1  2018KHAN28     222    92          1              1            1
# 2  2016FEIS01     222    94          3              2            2
# 3  2012PATE01     222    97          4              1            1
# 4  2021ZAJD03     222    97          4              1            1
# First 5 rows of WCA_export_RanksSingle.tsv:
#      personId eventId  best  worldRank  continentRank  countryRank
# 0  2021ZAJD03     222    43          1              1            1
# 1  2013MARC05     222    44          2              2            1
# 2  2018WANG35     222    47          3              1            1
# 3  2014CZAP01     222    49          4              3            2
# 4  2018KHAN28     222    50          5              1            1
# First 5 rows of WCA_export_Results.tsv:
#   competitionId eventId roundTypeId  pos  best  average  \
# 0  LyonOpen2007     333           1   15  1968     2128
# 1  LyonOpen2007     333           1   16  1731     2140
# 2  LyonOpen2007     333           1   17  2305     2637
# 3  LyonOpen2007     333           1   18  2452     2637
# 4  LyonOpen2007     333           1   19  2677     2906
#
#                 personName    personId formatId  value1  value2  value3  \
# 0            Etienne Amany  2007AMAN01        a    1968    2203    2138
# 1           Thomas Rouault  2004ROUA01        a    2222    2153    1731
# 2  Antoine Simon-Chautemps  2005SIMO01        a    3430    2581    2540
# 3           Irène Mallordy  2007MALL01        a    2715    2452    2868
# 4       Marlène Desmaisons  2007DESM01        a    2921    3184    2891
#
#    value4  value5 regionalSingleRecord regionalAverageRecord personCountryId
# 0    2139    2108                  AfR                   AfR   Cote d_Ivoire
# 1    2334    2046                  NaN                   NaN          France
# 2    2789    2305                  NaN                   NaN          France
# 3    2632    2564                  NaN                   NaN          France
# 4    2677    2907                  NaN                   NaN          France
# First 5 rows of WCA_export_RoundTypes.tsv:
#   id             cellName  final                 name  rank
# 0  0  Qualification round      0  Qualification round    19
# 1  1          First round      0          First round    29
# 2  2         Second round      0         Second round    50
# 3  3           Semi Final      0           Semi Final    79
# 4  b              B Final      0              B Final    39
# First 5 rows of WCA_export_Scrambles.tsv:
#             competitionId eventId groupId  isExtra roundTypeId  \
# 0  GaleriesDorianOpen2014   pyram       A        0           1
# 1  GaleriesDorianOpen2014   pyram       A        0           1
# 2  GaleriesDorianOpen2014   pyram       A        0           1
# 3  GaleriesDorianOpen2014   pyram       A        0           1
# 4  GaleriesDorianOpen2014   pyram       A        0           1
#
#                                 scramble  scrambleId  scrambleNum
# 0  U R' L' B U B' R' B' L' U L' u' r' b'           1            1
# 1      B' L' U' B U' L U' R B' R' L' u r           2            2
# 2        R' U R' L' B' U L' B' R L' U l'           3            3
# 3           L R' L U B R L R B R L' u' l           4            4
# 4     B' U R L' R B L' U' B' R' U' l' r'           5            5

# %% [markdown]
# I guess the simplest design is like this:
# For a given person (WCA ID / personId), get all of their results, and extract a distribution from which we can draw their estimated performance.
#
# This should have components:
# 1. Previous performance, mean and std dev
# 2. Recent performance, ie. more recent results should be weighted higher with some exponential decay according to the result date
# 3. Competition results, ie. results from competitions that are more competitive should be weighted higher. This can come later, but e.g. as a modifier we can see how much they over/underperform during championship competitions.
# 4. Competition results, as in when all competitors in a given competition underperformed their respective means, we can infer that there were confounding factors (e.g. scramble).
# 5. Some modifier on whether the competitors has broken PRs consistently and recently.
#
# Not sure what roundTypeId d, c, e mean, but "f" for finals seems consistent.
#
# Should probably tune this halflife somewhat toward whatever is mle for nationals

# %%
results = tables["WCA_export_Results.tsv"]
competitions = tables["WCA_export_Competitions.tsv"]

display(results.head())
display(competitions.head())
display(results.eventId.unique())
# Out:
#   competitionId eventId roundTypeId  pos  best  average  \
# 0  LyonOpen2007     333           1   15  1968     2128
# 1  LyonOpen2007     333           1   16  1731     2140
# 2  LyonOpen2007     333           1   17  2305     2637
# 3  LyonOpen2007     333           1   18  2452     2637
# 4  LyonOpen2007     333           1   19  2677     2906
#
#                 personName    personId formatId  value1  value2  value3  \
# 0            Etienne Amany  2007AMAN01        a    1968    2203    2138
# 1           Thomas Rouault  2004ROUA01        a    2222    2153    1731
# 2  Antoine Simon-Chautemps  2005SIMO01        a    3430    2581    2540
# 3           Irène Mallordy  2007MALL01        a    2715    2452    2868
# 4       Marlène Desmaisons  2007DESM01        a    2921    3184    2891
#
#    value4  value5 regionalSingleRecord regionalAverageRecord personCountryId
# 0    2139    2108                  AfR                   AfR   Cote d_Ivoire
# 1    2334    2046                  NaN                   NaN          France
# 2    2789    2305                  NaN                   NaN          France
# 3    2632    2564                  NaN                   NaN          France
# 4    2677    2907                  NaN                   NaN          France
#                              id                               name  \
# 0                 100Merito2018                   100º Mérito 2018
# 1    100YearsRepublicAnkara2023     100 Years Republic Ankara 2023
# 2  100YearsRepublicIstanbul2023   100 Years Republic İstanbul 2023
# 3      100YilMBACubeWeekend2023     100. Yıl MBA Cube Weekend 2023
# 4    10AniversarioGuatemala2023  Décimo Aniversario Guatemala 2023
#
#          cityName  countryId  \
# 0  Santarém, Pará     Brazil
# 1          Ankara     Turkey
# 2        İstanbul     Turkey
# 3        İstanbul     Turkey
# 4  Guatemala City  Guatemala
#
#                                          information  \
# 0  Qualquer pessoa que resolva o Cubo Mágico em m...
# 1  [TR] Kayıt sırasında adınızı ve soyadınızı lüt...
# 2  [TR] Kayıt sırasında adınızı ve soyadınızı lüt...
# 3  [TR] Kayıt sırasında adınızı ve soyadınızı lüt...
# 4  Ésta es una competencia conmemorativa en honor...
#
#                                                venue  \
# 0  [Mérito Pré-Vestibulares](https://www.facebook...
# 1   TMMOB Teoman Öztürk Öğrenci Evi ve Sosyal Tesisi
# 2  [Bil Koleji Ümraniye Yerleşkesi](https://bilok...
# 3  [MBA Okulları Çamlıca Yerleşkesi](https://www....
# 4               [Colegio Caré](https://care.edu.gt/)
#
#                                         venueAddress  \
# 0     Avenida Mendonça Furtado, 1120 - CEP: 68040050
# 1  Mehmet Akif Ersoy, 295. Sk. No:6, 06200 Yenima...
# 2  Cemil Meriç, Alemdağ Cd No:321, 34771 Dudullu ...
# 3  Küçük Çamlıca, Libadiye Cd. No:30, 34692 Üsküd...
# 4                            23 calle 15-45, zona 13
#
#                        venueDetails external_website  \
# 0  Próximo ao Colégio São Francisco              NaN
# 1                 6.kat / 6th floor              NaN
# 2                        Yemek katı              NaN
# 3           Yemekhane / Dining Hall              NaN
# 4                               NaN              NaN
#
#                            cellName  ...  longitude  cancelled  \
# 0                  100º Mérito 2018  ...  -54712597          0
# 1    100 Years Republic Ankara 2023  ...   32766238          0
# 2  100 Years Republic İstanbul 2023  ...   29142873          0
# 3    100. Yıl MBA Cube Weekend 2023  ...   29074717          0
# 4     10 Aniversario Guatemala 2023  ...  -90525865          1
#
#                                           eventSpecs  \
# 0                222 333 333bf 333ft 444 pyram skewb
# 1        222 333 333oh 444 555 clock pyram skewb sq1
# 2  222 333 333bf 333oh 444 555 clock pyram skewb sq1
# 3  222 333 333bf 333oh 444 555 666 777 clock minx...
# 4             222 333 333bf 333oh 444 555 minx pyram
#
#                                          wcaDelegate  \
# 0  [{Rafael de Andrade Cinoto}{mailto:rcinoto@wor...
# 1  [{Can Ersoy}{mailto:cersoy@worldcubeassociatio...
# 2  [{Mustafa Çamlıca}{mailto:mcamlica@worldcubeas...
# 3  [{Mustafa Çamlıca}{mailto:mcamlica@worldcubeas...
# 4  [{Adrián Ramírez}{mailto:aramirez@worldcubeass...
#
#                                            organiser  year  month  day  \
# 0  [{Davi de Andrade Iácono}{mailto:diacono@world...  2018      4   14
# 1  [{İskender Aznavur}{mailto:i.kuleli@gmail.com}...  2023     10   28
# 2  [{Alper Şakım}{mailto:alpersakim2@gmail.com}] ...  2023     10   28
# 3  [{Alper Şakım}{mailto:alpersakim2@gmail.com}] ...  2023     12   16
# 4    [{Nancy Ramírez}{mailto:nancy.r1116@gmail.com}]  2023     10   14
#
#    endMonth  endDay
# 0         4      14
# 1        10      29
# 2        10      29
# 3        12      17
# 4        10      15
#
# [5 rows x 21 columns]
# array(['333', '333oh', '444', '555', '333bf', '333mbo', 'minx', '333ft',
#        'mmagic', 'clock', '333fm', '222', 'magic', 'sq1', 'pyram',
#        '444bf', '555bf', '666', '777', '333mbf', 'skewb'], dtype=object)

# %%
person_id = '2014MILL04'
event = '333'

person_results = results[results["personId"] == person_id]
person_results = person_results.merge(
    competitions[['id', 'name', 'year', 'month', 'day']], how='left',
    left_on='competitionId', right_on='id')

display(person_results.head())

event_results = person_results[person_results['eventId'] == event][[
    'competitionId',
    'roundTypeId',
    'best', 'average', 'personName', 'personId', 'value1', 'value2', 'value3', 'value4',
    'value5', 'year', 'month', 'day'
]].assign(date=lambda x: pd.to_datetime(x[['year', 'month', 'day']]).dt.date).drop(
    columns=['year', 'month', 'day'])

value_columns = [col for col in event_results.columns if col.startswith("value")]
id_vars = [col for col in event_results.columns if col not in value_columns]

event_results = pd.melt(
    event_results,
    id_vars=id_vars,  
    value_vars=value_columns,   
    var_name="solve_number",   
    value_name="result"   
)

display(event_results.head())
# Out:
#        competitionId eventId roundTypeId  pos   best  average   personName  \
# 0  CuthbertsOpen2014     555           d   37  31035        0  Chris Mills
# 1  CuthbertsOpen2014     333           1   49   2586     2791  Chris Mills
# 2  CuthbertsOpen2014   skewb           f   19   1629     1934  Chris Mills
# 3  CuthbertsOpen2014     222           d   47    931     1486  Chris Mills
# 4  CuthbertsOpen2014     444           d   44  19567        0  Chris Mills
#
#      personId formatId  value1  value2  value3  value4  value5  \
# 0  2014MILL04        a   31060   31035       0       0       0
# 1  2014MILL04        a    2586    2866    2722    2784    3251
# 2  2014MILL04        a    2176    4444    1769    1629    1858
# 3  2014MILL04        a     979    1834     931    1646      -1
# 4  2014MILL04        a   19567   19669       0       0       0
#
#   regionalSingleRecord regionalAverageRecord personCountryId  \
# 0                  NaN                   NaN  United Kingdom
# 1                  NaN                   NaN  United Kingdom
# 2                  NaN                   NaN  United Kingdom
# 3                  NaN                   NaN  United Kingdom
# 4                  NaN                   NaN  United Kingdom
#
#                   id                 name  year  month  day
# 0  CuthbertsOpen2014  Cuthberts Open 2014  2014     10   11
# 1  CuthbertsOpen2014  Cuthberts Open 2014  2014     10   11
# 2  CuthbertsOpen2014  Cuthberts Open 2014  2014     10   11
# 3  CuthbertsOpen2014  Cuthberts Open 2014  2014     10   11
# 4  CuthbertsOpen2014  Cuthberts Open 2014  2014     10   11
#                 competitionId roundTypeId  best  average   personName  \
# 0           CuthbertsOpen2014           1  2586     2791  Chris Mills
# 1            OxfordWinter2014           1  1856     2143  Chris Mills
# 2            HarrowSpring2015           1  1700     1990  Chris Mills
# 3  WelcomeBackToGuildford2015           2  1555     1737  Chris Mills
# 4  WelcomeBackToGuildford2015           1  1516     1599  Chris Mills
#
#      personId        date solve_number  result
# 0  2014MILL04  2014-10-11       value1    2586
# 1  2014MILL04  2014-12-20       value1    2215
# 2  2014MILL04  2015-02-28       value1    2429
# 3  2014MILL04  2015-04-11       value1    1555
# 4  2014MILL04  2015-04-11       value1    1516

# %%
event_results['date'] = pd.to_datetime(event_results['date'])
greatest_date = event_results['date'].max()

event_results['time_difference'] = (greatest_date.year - event_results[
    'date'].dt.year) * 12 + (greatest_date.month - event_results['date'].dt.month)

halflife = 3
event_results['weight'] = 2 ** (-event_results['time_difference'] / halflife)

event_results.sort_values(['date'], ascending=False).head(25)

weighted_mean = np.average(event_results['result'], weights=event_results['weight'])
print(f"Weighted mean of results: {weighted_mean:.2f}")

n_bootstrap = 1000  # Number of resamples
bootstrap_means = []

for _ in range(n_bootstrap):
    resampled = event_results.sample(n=len(event_results), replace=True, weights=event_results['weight'])
    resampled_mean = np.mean(resampled['result'])
    bootstrap_means.append(resampled_mean)

bootstrap_means = np.array(bootstrap_means)
print(f"Bootstrap Resampling Mean: {np.mean(bootstrap_means):.2f}")
print(f"Bootstrap Resampling 95% CI: {np.percentile(bootstrap_means, [2.5, 97.5])}")


plt.hist(bootstrap_means, bins=30, alpha=0.7, edgecolor='k')
plt.title("Bootstrap Weighted Results")
plt.xlabel("Weighted Mean")
plt.show()
# Out:
# Weighted mean of results: 707.70
# Bootstrap Resampling Mean: 707.82
# Bootstrap Resampling 95% CI: [701.53809333 713.93325333]

# %%
event_results.sort_values('date', ascending=False).drop_duplicates(subset='average').head(40)[['competitionId', 'roundTypeId', 'best', 'average', 'weight', 'date']]
# Out:
#                competitionId roundTypeId  best  average    weight       date
# 1874     MaxSpeedMilford2024           f   573      663  1.000000 2024-11-30
# 373      MaxSpeedMilford2024           1   622      661  1.000000 2024-11-30
# 1495       HastyHastings2024           1   506      669  1.000000 2024-11-23
# 1122       HastyHastings2024           f   590      692  1.000000 2024-11-23
# 1121       HastyHastings2024           2   648      721  1.000000 2024-11-23
# ...                      ...         ...   ...      ...       ...        ...
# 1835  GoingBacktotheGong2024           1   544      736  0.125000 2024-02-10
# 709       BrisbaneSummer2024           f   588      714  0.125000 2024-02-03
# 707       BrisbaneSummer2024           2   638      660  0.125000 2024-02-03
# 333       BrisbaneSummer2024           3   627      719  0.125000 2024-02-03
# 705      MelbourneSummer2024           f   603      782  0.099213 2024-01-19
#
# [40 rows x 6 columns]

# %%
grouped = event_results.groupby(['date', 'roundTypeId'])
group_std_devs = grouped['result'].std().reset_index(
    name='group_std_dev')  # Calculate std deviation
group_std_devs['time_difference'] = (greatest_date.year - group_std_devs[
    'date'].dt.year) * 12 + (greatest_date.month - group_std_devs[
    'date'].dt.month)

group_std_devs['weight'] = 2 ** (-group_std_devs['time_difference'] / halflife)

weighted_avg_std_dev = np.average(group_std_devs['group_std_dev'],
                                  weights=group_std_devs['weight'])

print(f"\nWeighted Average Standard Deviation: {weighted_avg_std_dev:.2f}")
group_std_devs.sort_values('date', ascending=False).head(10)
# Out:
# Weighted Average Standard Deviation: 110.85
#           date roundTypeId  group_std_dev  time_difference    weight
# 374 2024-11-30           f     163.985670                0  1.000000
# 373 2024-11-30           1      82.918635                0  1.000000
# 372 2024-11-23           f     107.566259                0  1.000000
# 371 2024-11-23           2     197.800910                0  1.000000
# 370 2024-11-23           1      97.330365                0  1.000000
# 369 2024-10-12           f      80.363549                1  0.793701
# 368 2024-10-12           2      49.176214                1  0.793701
# 367 2024-10-12           1      55.138915                1  0.793701
# 365 2024-09-28           2     148.396429                2  0.629961
# 364 2024-09-28           1      80.395895                2  0.629961
